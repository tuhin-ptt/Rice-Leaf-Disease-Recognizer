# %% [markdown]
# ### Google Drive Connection

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/Rice Leaf Disease
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Rice Leaf Disease

# %% [markdown]
# ### Importing necessary modules/libraries

# %%
import numpy as np
import pickle
import cv2
from os import listdir
import tensorflow as tf
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from IPython.display import HTML
from base64 import b64encode
import matplotlib.pyplot as plt

# %% [markdown]
# ### parameters declarations

# %%
initial_lr = .001
batch_size = 8
default_image_size = tuple((128, 128))
image_size = 0
width=256
height=256
depth=3

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# ### Loading and preprocessing Dataset

# %%
directory_root = 'dataset'
image_list, label_list = [], []
try:
    print("Loading images ...")
    root_dir = listdir(directory_root)
    for disease_folder in root_dir:
        image_pth = listdir(f"{directory_root}/{disease_folder}")
            
        for image_file in image_pth:
            image_dir = f"{directory_root}/{disease_folder}/{image_file}"
            if ".jpg" in image_file or ".JPG" in image_file or ".png" in image_file or ".PNG" in image_file:
                image_list.append(convert_image_to_array(image_dir))
                label_list.append(disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# Loading images ...
# [INFO] Image loading completed

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
# normalizing image arrays
np_image_list = np.array(image_list, dtype=np.float16) / 255.0

# %%
# spliting dataset for training and testing 75/25 ratio
print("Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.25, random_state = 42)
# Out:
# Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# ### Defining model

# %%
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, \
     Add, Dense, BatchNormalization, ReLU, MaxPool2D, GlobalAvgPool2D

def conv_bn(x, filters, kernel_size, strides=1):
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding='same',
               use_bias=False)(x)
    x = BatchNormalization()(x)
    return x


def sep_bn(x, filters, kernel_size, strides=1):
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    return x


def entry_flow(x):
    x = conv_bn(x, filters=32, kernel_size=3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters=64, kernel_size=3)
    tensor = ReLU()(x)

    x = sep_bn(tensor, filters=128, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=128, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=128, kernel_size=1, strides=2)

    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, filters=256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=256, kernel_size=1, strides=2)

    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=728, kernel_size=1, strides=2)
    x = Add()([tensor, x])

    return x


def middle_flow(tensor):
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters=728, kernel_size=3)
        x = ReLU()(x)
        x = sep_bn(x, filters=728, kernel_size=3)
        x = ReLU()(x)
        x = sep_bn(x, filters=728, kernel_size=3)

        tensor = Add()([tensor, x])

    return tensor


def exit_flow(tensor):
    x = ReLU()(tensor)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=1024, kernel_size=3)
    x = MaxPool2D(3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=1024, kernel_size=1, strides=2)

    x = Add()([tensor, x])
    x = sep_bn(x, filters=1536, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=2048, kernel_size=3)
    x = ReLU()(x)
    x = GlobalAvgPool2D()(x)
    x = Dense(units=4, activation='softmax')(x)

    return x


input = Input(shape=[128, 128, 3])

x = entry_flow(input)
x = middle_flow(x)
output = exit_flow(x)
model = Model(input, output)

# %%
import tensorflow as tf  
#stop training is model accuracy reached 99% 
class myCallback(tf.keras.callbacks.Callback): 
  def on_epoch_end(self, epoch, logs={}): 
    if(logs.get('val_acc')>0.99): 
      self.model.stop_training = True

# %%
import tensorflow as tf  
checkpoint_filepath='/'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
epochs = 30
opt = Adam(learning_rate=initial_lr, decay=initial_lr / epochs)
# distribution
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["acc"])
callbacks = myCallback()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   18432       ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 64, 64, 64)   0           ['batch_normalization_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 64, 64, 128)  8768       ['re_lu_1[0][0]']
#  v2D)
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['separable_conv2d[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 64, 64, 128)  0           ['batch_normalization_2[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 64, 64, 128)  17536      ['re_lu_2[0][0]']
#  onv2D)
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 128)  8192        ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 128)  0           ['batch_normalization_3[0][0]']
#
#  add (Add)                      (None, 32, 32, 128)  0           ['batch_normalization_4[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 32, 32, 128)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 32, 32, 256)  33920      ['re_lu_3[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 32, 32, 256)  67840      ['re_lu_4[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 256)  32768       ['batch_normalization_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 16, 16, 256)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 16, 16, 728)  188672     ['re_lu_5[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 728)  2912       ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 16, 16, 728)  0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 16, 16, 728)  536536     ['re_lu_6[0][0]']
#  onv2D)
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 728)    186368      ['batch_normalization_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 728)  2912       ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 728)   2912        ['conv2d_4[0][0]']
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 728)   0           ['batch_normalization_9[0][0]']
#
#  add_2 (Add)                    (None, 8, 8, 728)    0           ['batch_normalization_10[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 8, 8, 728)    0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 8, 8, 728)   536536      ['re_lu_7[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_6[0][0]']
#  ormalization)
#
#  re_lu_8 (ReLU)                 (None, 8, 8, 728)    0           ['batch_normalization_11[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 8, 8, 728)   536536      ['re_lu_8[0][0]']
#  onv2D)
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_7[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 8, 8, 728)    0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 8, 8, 728)   536536      ['re_lu_9[0][0]']
#  onv2D)
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 8, 8, 728)    0           ['add_2[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  re_lu_10 (ReLU)                (None, 8, 8, 728)    0           ['add_3[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 8, 8, 728)   536536      ['re_lu_10[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 8, 8, 728)   536536      ['re_lu_11[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 8, 8, 728)   536536      ['re_lu_12[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 728)    0           ['add_3[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  re_lu_13 (ReLU)                (None, 8, 8, 728)    0           ['add_4[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 8, 8, 728)   536536      ['re_lu_13[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 8, 8, 728)   536536      ['re_lu_14[0][0]']
#  Conv2D)
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 8, 8, 728)   536536      ['re_lu_15[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 728)    0           ['add_4[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  re_lu_16 (ReLU)                (None, 8, 8, 728)    0           ['add_5[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 8, 8, 728)   536536      ['re_lu_16[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 8, 8, 728)   536536      ['re_lu_17[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_21[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 8, 8, 728)   536536      ['re_lu_18[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 728)    0           ['add_5[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  re_lu_19 (ReLU)                (None, 8, 8, 728)    0           ['add_6[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 8, 8, 728)   536536      ['re_lu_19[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_23[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 8, 8, 728)   536536      ['re_lu_20[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_20 (Separable  (None, 8, 8, 728)   536536      ['re_lu_21[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 728)    0           ['add_6[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  re_lu_22 (ReLU)                (None, 8, 8, 728)    0           ['add_7[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 8, 8, 728)   536536      ['re_lu_22[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_26[0][0]']
#
#  separable_conv2d_22 (Separable  (None, 8, 8, 728)   536536      ['re_lu_23[0][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 8, 8, 728)   536536      ['re_lu_24[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 8, 8, 728)    0           ['add_7[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  re_lu_25 (ReLU)                (None, 8, 8, 728)    0           ['add_8[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 8, 8, 728)   536536      ['re_lu_25[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 8, 8, 728)   536536      ['re_lu_26[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_30[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 8, 8, 728)   536536      ['re_lu_27[0][0]']
#  Conv2D)
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 8, 8, 728)    0           ['add_8[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  re_lu_28 (ReLU)                (None, 8, 8, 728)    0           ['add_9[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 8, 8, 728)   536536      ['re_lu_28[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_32[0][0]']
#
#  separable_conv2d_28 (Separable  (None, 8, 8, 728)   536536      ['re_lu_29[0][0]']
#  Conv2D)
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_33[0][0]']
#
#  separable_conv2d_29 (Separable  (None, 8, 8, 728)   536536      ['re_lu_30[0][0]']
#  Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_29[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 8, 8, 728)    0           ['add_9[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  re_lu_31 (ReLU)                (None, 8, 8, 728)    0           ['add_10[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 8, 8, 728)   536536      ['re_lu_31[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 728)   2912        ['separable_conv2d_30[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 8, 8, 728)    0           ['batch_normalization_35[0][0]']
#
#  separable_conv2d_31 (Separable  (None, 8, 8, 1024)  752024      ['re_lu_32[0][0]']
#  Conv2D)
#
#  conv2d_5 (Conv2D)              (None, 4, 4, 1024)   745472      ['add_10[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 1024)  4096        ['separable_conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_5[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 1024)  0           ['batch_normalization_36[0][0]']
#
#  add_11 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_37[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  separable_conv2d_32 (Separable  (None, 4, 4, 1536)  1582080     ['add_11[0][0]']
#  Conv2D)
#
#  batch_normalization_38 (BatchN  (None, 4, 4, 1536)  6144        ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 4, 4, 1536)   0           ['batch_normalization_38[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 4, 4, 2048)  3159552     ['re_lu_33[0][0]']
#  Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 2048)  8192        ['separable_conv2d_33[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 4, 4, 2048)   0           ['batch_normalization_39[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['re_lu_34[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            8196        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training model

# %%
# test data is used as validation data
history = model.fit(
    aug.flow(x_train, y_train, batch_size=batch_size),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epochs, verbose=1,
    callbacks=[model_checkpoint_callback]
    )
# Out:
# Epoch 1/30
# 556/556 [==============================] - ETA: 0s - loss: 0.9267 - acc: 0.6584
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 44s 72ms/step - loss: 0.9267 - acc: 0.6584 - val_loss: 1.0691 - val_acc: 0.5677
# Epoch 2/30
# 556/556 [==============================] - ETA: 0s - loss: 0.6478 - acc: 0.7504
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 69ms/step - loss: 0.6478 - acc: 0.7504 - val_loss: 1.2134 - val_acc: 0.6606
# Epoch 3/30
# 556/556 [==============================] - ETA: 0s - loss: 0.5092 - acc: 0.8037
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 69ms/step - loss: 0.5092 - acc: 0.8037 - val_loss: 0.6914 - val_acc: 0.7589
# Epoch 4/30
# 556/556 [==============================] - ETA: 0s - loss: 0.4135 - acc: 0.8502
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 41s 73ms/step - loss: 0.4135 - acc: 0.8502 - val_loss: 0.2742 - val_acc: 0.8970
# Epoch 5/30
# 556/556 [==============================] - ETA: 0s - loss: 0.3463 - acc: 0.8774
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 38s 69ms/step - loss: 0.3463 - acc: 0.8774 - val_loss: 0.2003 - val_acc: 0.9374
# Epoch 6/30
# 556/556 [==============================] - ETA: 0s - loss: 0.2866 - acc: 0.9033
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 69ms/step - loss: 0.2866 - acc: 0.9033 - val_loss: 0.3061 - val_acc: 0.8559
# Epoch 7/30
# 556/556 [==============================] - ETA: 0s - loss: 0.2419 - acc: 0.9128
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 40s 71ms/step - loss: 0.2419 - acc: 0.9128 - val_loss: 0.1754 - val_acc: 0.9320
# Epoch 8/30
# 556/556 [==============================] - ETA: 0s - loss: 0.1980 - acc: 0.9305
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.1980 - acc: 0.9305 - val_loss: 0.1147 - val_acc: 0.9535
# Epoch 9/30
# 556/556 [==============================] - ETA: 0s - loss: 0.1680 - acc: 0.9422
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 41s 74ms/step - loss: 0.1680 - acc: 0.9422 - val_loss: 0.1080 - val_acc: 0.9697
# Epoch 10/30
# 556/556 [==============================] - ETA: 0s - loss: 0.1639 - acc: 0.9456
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 71ms/step - loss: 0.1639 - acc: 0.9456 - val_loss: 0.0863 - val_acc: 0.9710
# Epoch 11/30
# 556/556 [==============================] - ETA: 0s - loss: 0.1249 - acc: 0.9557
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.1249 - acc: 0.9557 - val_loss: 0.1180 - val_acc: 0.9643
# Epoch 12/30
# 556/556 [==============================] - ETA: 0s - loss: 0.1084 - acc: 0.9631
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.1084 - acc: 0.9631 - val_loss: 0.0238 - val_acc: 0.9906
# Epoch 13/30
# 556/556 [==============================] - ETA: 0s - loss: 0.1051 - acc: 0.9656
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.1051 - acc: 0.9656 - val_loss: 0.0236 - val_acc: 0.9906
# Epoch 14/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0980 - acc: 0.9672
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 41s 74ms/step - loss: 0.0980 - acc: 0.9672 - val_loss: 0.0146 - val_acc: 0.9973
# Epoch 15/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0875 - acc: 0.9728
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 71ms/step - loss: 0.0875 - acc: 0.9728 - val_loss: 0.0192 - val_acc: 0.9973
# Epoch 16/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0815 - acc: 0.9730
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 40s 71ms/step - loss: 0.0815 - acc: 0.9730 - val_loss: 0.0221 - val_acc: 0.9926
# Epoch 17/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0697 - acc: 0.9782
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0697 - acc: 0.9782 - val_loss: 0.0405 - val_acc: 0.9879
# Epoch 18/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0573 - acc: 0.9820
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 41s 73ms/step - loss: 0.0573 - acc: 0.9820 - val_loss: 0.0047 - val_acc: 0.9993
# Epoch 19/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0599 - acc: 0.9784
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0599 - acc: 0.9784 - val_loss: 0.0190 - val_acc: 0.9926
# Epoch 20/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0556 - acc: 0.9820
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 40s 71ms/step - loss: 0.0556 - acc: 0.9820 - val_loss: 0.1907 - val_acc: 0.9401
# Epoch 21/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0578 - acc: 0.9825
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0578 - acc: 0.9825 - val_loss: 0.0141 - val_acc: 0.9953
# Epoch 22/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0597 - acc: 0.9811
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 41s 74ms/step - loss: 0.0597 - acc: 0.9811 - val_loss: 0.0365 - val_acc: 0.9919
# Epoch 23/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0434 - acc: 0.9836
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 71ms/step - loss: 0.0434 - acc: 0.9836 - val_loss: 0.1062 - val_acc: 0.9751
# Epoch 24/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0540 - acc: 0.9822
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0540 - acc: 0.9822 - val_loss: 0.0041 - val_acc: 0.9993
# Epoch 25/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0412 - acc: 0.9867
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 40s 72ms/step - loss: 0.0412 - acc: 0.9867 - val_loss: 0.0408 - val_acc: 0.9859
# Epoch 26/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0551 - acc: 0.9843
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 41s 73ms/step - loss: 0.0551 - acc: 0.9843 - val_loss: 0.0256 - val_acc: 0.9933
# Epoch 27/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0392 - acc: 0.9883
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0392 - acc: 0.9883 - val_loss: 0.0095 - val_acc: 0.9987
# Epoch 28/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0316 - acc: 0.9897
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0316 - acc: 0.9897 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 29/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0453 - acc: 0.9865
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 70ms/step - loss: 0.0453 - acc: 0.9865 - val_loss: 0.0190 - val_acc: 0.9919
# Epoch 30/30
# 556/556 [==============================] - ETA: 0s - loss: 0.0243 - acc: 0.9910
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 556/556 [==============================] - 39s 69ms/step - loss: 0.0243 - acc: 0.9910 - val_loss: 0.0034 - val_acc: 0.9987

# %%
#save model
model.save('RLDR_model.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.subplot(1,2,2)
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Model accuracy on test data

# %%
model = tf.keras.models.load_model('RLDR_model.h5')
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 47/47 [==============================] - 11s 48ms/step - loss: 0.0032 - acc: 0.9993
# Test Accuracy: 99.93265867233276

# %%
print('Diseases:', label_binarizer.classes_)
# Out:
# Diseases: ['Bacterialblight' 'Blast' 'Brownspot' 'Tungro']

# %% [markdown]
# ### Recognizing disease from custom image

# %%
def recognize(image_dir):
  img = open(image_dir, 'rb').read()
  img_url = 'data:image/jpeg;base64,' + b64encode(img).decode()
  print('Input image:')
  display(HTML("<img src='%s' %s%s>" % (img_url, 128, 128)))

  maps = {0:'Bacterialblight', 1:'Blast', 2:'Brownspot', 3:'Tungro'}
  img_arr = convert_image_to_array(image_dir)
  img_arr = np.array(img_arr, dtype=np.float16) / 255.0
  img_arr = np.expand_dims(img_arr, 0)
  preds = model.predict(img_arr)
  label = np.argmax(preds)
  print('Recognized disease:', maps[label])

# %%
test_image = 'dataset/Bacterialblight/BACTERAILBLIGHT3_009.jpg'
recognize(test_image)
# Out:
# Input image:
# <img src='data:image/jpeg;base64,...' 128128>
# Recognized disease: Bacterialblight
